# %% [markdown]
# ### Comparing DBSCAN in scikit learn, pyclustering and hdbscan

# %%
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh import palettes

import pandas as pd
import numpy as np
from scipy.spatial.distance import euclidean
import itertools

from pyclustering.cluster.dbscan import dbscan
import hdbscan

# %load_ext memory_profiler

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ee85a214-55fd-4e69-b716-31093f66c365">Loading BokehJS ...</span>
#     </div>

# %%
# helper functions
def plot_data(X):
    if X.shape[1] > 2:
        pca = PCA(n_components=2, random_state=0)
        pca.fit(X.transpose())
        x1, x2 = pca.components_
        variance_explained = sum(pca.explained_variance_ratio_) *100
        title="first two components explained {0: .1f} % of variance".format(variance_explained)
        p = figure(title=title)
    else:    
        p = figure()
        x1, x2 = X[:, 0], X[:, 1]
    p.scatter(x1, x2)
    show(p)
    
    
def plot_cluster(X, y_pred, centers=[], xlabel="component 1", ylabel="component 2", title=""):
    colors = np.array([palettes.Set1[9][i] for i in y_pred])
    TOOLS="hover,crosshair,box_zoom, reset,save"
    p = figure(tools=TOOLS, plot_height=450, plot_width=500, title=title)
    p.scatter(X[:,0], X[:, 1], fill_alpha=0.5, line_color=None, fill_color=colors)
    if len(centers) != 0:
        for num, center in enumerate(centers):
            text = Label(x=center[0], y=center[1], text=str(num))
            p.add_layout(text)
        p.diamond(centers[:,0], centers[:,1], fill_color="black", line_color="black")
    p.xaxis.axis_label = xlabel 
    p.yaxis.axis_label = ylabel
    return p


def convert_X_to_pyclustering_format(X):
    return [list(i) for i in X]

def convert_y_to_plot_format(X, y_pred):
    new_y = [-1] * len(X)
    for cluster_num, indices in enumerate(y_pred):
        for i in indices:
            new_y[i] = cluster_num
    return np.array(new_y)

# %%
# simulate data points with 3 clusters
X, y = make_blobs(n_samples=1000, n_features=2, centers=3, random_state=13)

transformation = [[ 0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)
plot_data(X_aniso)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d97cdd20-d90d-4b4c-8350-553622a484ca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d97cdd20-d90d-4b4c-8350-553622a484ca");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d97cdd20-d90d-4b4c-8350-553622a484ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd97cdd20-d90d-4b4c-8350-553622a484ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5c608fa2-4da0-435d-9f00-0b4793044e9d":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"0994709e-2e05-4ca5-8afc-a2c79cc93d05","subtype":"Figure","type":"Plot"},"ticker":{"id":"88754861-9190-490e-866d-0062e71db1e7","type":"BasicTicker"}},"id":"68c59512-fd80-43f0-84ae-cf809fffd1ab","type":"Grid"},{"attributes":{"below":[{"id":"afcf33ba-d0a2-477d-804a-f3e6935ebff9","type":"LinearAxis"}],"left":[{"id":"850e7d79-5e67-4120-9e16-6278efa455ef","type":"LinearAxis"}],"renderers":[{"id":"afcf33ba-d0a2-477d-804a-f3e6935ebff9","type":"LinearAxis"},{"id":"a3560d8b-35df-4614-88e1-bf04bc226ed7","type":"Grid"},{"id":"850e7d79-5e67-4120-9e16-6278efa455ef","type":"LinearAxis"},{"id":"68c59512-fd80-43f0-84ae-cf809fffd1ab","type":"Grid"},{"id":"5079f460-ce4f-4aed-81fe-51baf5a659de","type":"BoxAnnotation"},{"id":"e9a8bbd5-6162-4133-9a2e-dd1a63689fc0","type":"GlyphRenderer"}],"title":{"id":"46486f15-781e-4574-96b1-b9747533df6a","type":"Title"},"tool_events":{"id":"243af21c-de52-4457-ac95-fa75a3014eda","type":"ToolEvents"},"toolbar":{"id":"265e1e70-bbad-4889-9ee2-ac8fabe120f2","type":"Toolbar"},"x_range":{"id":"8d65d8fa-de07-4f74-b68d-4df74e0cc4a3","type":"DataRange1d"},"y_range":{"id":"6e07f67d-7430-40ef-ac6f-49e5d9da84c2","type":"DataRange1d"}},"id":"0994709e-2e05-4ca5-8afc-a2c79cc93d05","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"80d0a1a0-a83a-45b6-afc6-0ac6ec94de8d","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"efd0f90b-e326-45f6-a709-ac9daea9215d","type":"ColumnDataSource"},"glyph":{"id":"1821f07a-ff41-4a53-ba3b-d0497b7c63d1","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ee43fd27-d2be-400a-bd86-6ecd523be02d","type":"Circle"},"selection_glyph":null},"id":"e9a8bbd5-6162-4133-9a2e-dd1a63689fc0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"0994709e-2e05-4ca5-8afc-a2c79cc93d05","subtype":"Figure","type":"Plot"}},"id":"9f681d66-6aba-412c-b9a5-a4bba4917eb9","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"d0b4fb8e-725f-4e22-b73c-569084149067","type":"BasicTickFormatter"},"plot":{"id":"0994709e-2e05-4ca5-8afc-a2c79cc93d05","subtype":"Figure","type":"Plot"},"ticker":{"id":"5d009422-ef81-4b98-8e0b-e4b0fbac5076","type":"BasicTicker"}},"id":"afcf33ba-d0a2-477d-804a-f3e6935ebff9","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"efd0f90b-e326-45f6-a709-ac9daea9215d","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"80d0a1a0-a83a-45b6-afc6-0ac6ec94de8d","type":"BasicTickFormatter"},"plot":{"id":"0994709e-2e05-4ca5-8afc-a2c79cc93d05","subtype":"Figure","type":"Plot"},"ticker":{"id":"88754861-9190-490e-866d-0062e71db1e7","type":"BasicTicker"}},"id":"850e7d79-5e67-4120-9e16-6278efa455ef","type":"LinearAxis"},{"attributes":{},"id":"d0b4fb8e-725f-4e22-b73c-569084149067","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b1212f8a-b3f3-40ee-89a1-07f657922593","type":"PanTool"},{"id":"9f681d66-6aba-412c-b9a5-a4bba4917eb9","type":"WheelZoomTool"},{"id":"180a314a-7e39-4399-abba-8e9e2a822b53","type":"BoxZoomTool"},{"id":"59e88a25-6424-4b40-8f69-cef7add81410","type":"SaveTool"},{"id":"4119114f-213f-4916-941c-8a59fd6db14e","type":"ResetTool"},{"id":"3d477a67-86fc-4c2a-b8e0-14f3f350294c","type":"HelpTool"}]},"id":"265e1e70-bbad-4889-9ee2-ac8fabe120f2","type":"Toolbar"},{"attributes":{},"id":"243af21c-de52-4457-ac95-fa75a3014eda","type":"ToolEvents"},{"attributes":{"callback":null},"id":"8d65d8fa-de07-4f74-b68d-4df74e0cc4a3","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1821f07a-ff41-4a53-ba3b-d0497b7c63d1","type":"Circle"},{"attributes":{"plot":{"id":"0994709e-2e05-4ca5-8afc-a2c79cc93d05","subtype":"Figu ...

# %%
sk_kmeans = KMeans(n_clusters=3)
y_pred = sk_kmeans.fit_predict(X_aniso)
p0 = plot_cluster(X_aniso, y_pred, title="scikit learn Kmeans")
show(p0)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="925e8ead-2654-4662-9136-a4c034425d92"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("925e8ead-2654-4662-9136-a4c034425d92");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("925e8ead-2654-4662-9136-a4c034425d92");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '925e8ead-2654-4662-9136-a4c034425d92' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"
#e41a1c","#e41a1c","#e41a1c","#e41a1c","#e41a1c","#e41a1c","#377eb8","#e41a1c","#4daf4a","#4daf4a","#999999","#e41a1c","#4daf4a","#4daf4a","#e41a1c","#e41a1c","#999999","#e41a1c","#e41a1c","#e41a1c","#377eb8","#e41a1c","#377eb8","#4daf4a","#4daf4a","#999999","#377eb8","#377eb8","#e41a1c","#e41a1c","#999999","#377eb8","#377eb8","#377eb8","#4daf4a","#4daf4a","#e41a1c","#4daf4a","#4daf4a","#999999","#e41a1c","#e41a1c","#e41a1c","#4daf4a","#4daf4a","#999999","#e41a1c","#e41a1c","#999999","#e41a1c","#4daf4a","#377eb8","#e41a1c","#4daf4a","#999999","#999999","#377eb8","#4daf4a","#999999","#999999","#377eb8","#4daf4a","#e41a1c","#4daf4a","#999999","#4daf4a","#4daf4a","#e41a1c","#4daf4a","#377eb8","#e41a1c","#377eb8","#e41a1c","#e41a1c","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#4daf4a","#377eb8","#e41a1c","#377eb8","#e41a1c","#e41a1c","#e41a1c","#4daf4a","#999999","#999999","#4daf4a","#4daf4a","#377eb8","#999999","#999999","#4daf4a","#4daf4a","#377eb8","#e41a1c","#377eb8","#4daf4a","#e41a1c","#4daf4a","#e41a1c","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#e41a1c","#377eb8","#4daf4a","#e41a1c","#999999","#4daf4a","#4daf4a","#377eb8","#4daf4a","#999999","#377eb8","#377eb ...

# %%
def pc_dbscan_two_step():
    pc_dbscan = dbscan(convert_X_to_pyclustering_format(X_aniso), 0.35, 25)
    pc_dbscan.process()
    return pc_dbscan
# %memit pc_dbscan_two_step()
# %timeit pc_dbscan_two_step()

pc_dbscan = pc_dbscan_two_step()
y_pred = convert_y_to_plot_format(X_aniso, pc_dbscan.get_clusters())
p2 = plot_cluster(X_aniso, y_pred, title="pyclustering dbscan")
show(p2)
# Out:
# peak memory: 187.51 MiB, increment: 0.00 MiB
# 1 loop, best of 3: 1.61 s per loop
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b065ce87-f53c-42d6-9fd5-fb1914ca477b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b065ce87-f53c-42d6-9fd5-fb1914ca477b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b065ce87-f53c-42d6-9fd5-fb1914ca477b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b065ce87-f53c-42d6-9fd5-fb1914ca477b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4420bed5-6ec8-4737-85a2-ab4b94f79104":{"roots":{"references":[{"attributes":{"plot":null,"text":"pyclustering dbscan"},"id":"5239d18d-ddf5-4fb2-ad37-1837280da6e5","type":"Title"},{"attributes":{"plot":{"id":"a9f47c84-2a3b-4716-997a-db64eef322b3","subtype":"Figure","type":"Plot"}},"id":"b952a0f1-0eb3-4d88-bcea-e3b19db69f80","type":"CrosshairTool"},{"attributes":{"overlay":{"id":"455a4e90-fe70-44b4-8c98-2d8ea5ccc5f9","type":"BoxAnnotation"},"plot":{"id":"a9f47c84-2a3b-4716-997a-db64eef322b3","subtype":"Figure","type":"Plot"}},"id":"c2e85107-6f2b-4a52-832d-dfe1fa55f53b","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"a9f47c84-2a3b-4716-997a-db64eef322b3","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0290ab0-43d3-43d7-b21d-edbca205943d","type":"BasicTicker"}},"id":"ca7ae268-c7b9-464e-a4c8-fc1255c71102","type":"Grid"},{"attributes":{"callback":null},"id":"31333eb0-5604-4a82-a472-608c95e61a18","type":"DataRange1d"},{"attributes":{"plot":{"id":"a9f47c84-2a3b-4716-997a-db64eef322b3","subtype":"Figure","type":"Plot"}},"id":"b1d55bdb-1631-4779-bec4-5cab37b928c5","type":"SaveTool"},{"attributes":{"plot":{"id":"a9f47c84-2a3b-4716-997a-db64eef322b3","subtype":"Figure","type":"Plot"}},"id":"a5de1d32-a94b-421f-aebe-4672727d2b21","type":"ResetTool"},{"attributes":{"data_source":{"id":"44c73867-e406-4ab9-9f0a-d67118ae00e5","type":"ColumnDataSource"},"glyph":{"id":"59eb816b-8a0d-44c1-b092-8e4597872a4e","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"773a5865-bd82-49e4-a970-07cc52085a4d","type":"Circle"},"selection_glyph":null},"id":"e614dd3b-d968-4e78-a5fc-754dae24ff55","type":"GlyphRenderer"},{"attributes":{},"id":"9c3b5210-f186-4000-b7cb-8771724ac205","type":"BasicTickFormatter"},{"attributes":{},"id":"4ae0e474-5e8e-43c4-9a18-fc725b9a582f","type":"ToolEvents"},{"attributes":{},"id":"eaf4a48d-501d-4ec8-a583-b70736ea7b4e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","fill_color"],"data":{"fill_color":["#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#4daf4a","#999999","#377eb8","#e41a1c","#999999","#e41a1c","#4daf4a","#999999","#4daf4a","#377eb8","#4daf4a","#e41a1c","#4daf4a","#e41a1c","#377eb8","#377eb8","#377eb8","#4daf4a","#999999","#999999","#377eb8","#e41a1c","#999999","#e41a1c","#377eb8","#4daf4a","#377eb8","#e41a1c","#377eb8","#377eb8","#999999","#e41a1c","#e41a1c","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#999999","#4daf4a","#4daf4a","#4daf4a","#4daf4a","#377eb8","#377eb8","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#377eb8","#4daf4a","#e41a1c","#4daf4a","#377eb8","#4daf4a","#e41a1c","#4daf4a","#377eb8","#e41a1c","#999999","#e41a1c","#e41a1c","#4daf4a","#e41a1c","#377eb8","#e41a1c","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#4daf4a","#4daf4a","#999999","#e41a1c","#999999","#e41a1c","#4daf4a","#4daf4a","#999999","#377eb8","#377eb8","#999999","#377eb8","#377eb8","#377eb8","#4daf4a","#377eb8","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#e41a1c","#999999","#4daf4a","#e41a1c","#377eb8","#999999","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#4daf4a","#e41a1c","#4daf4a","#377eb8","#377eb8","#e41a1c","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#e41a1c","#e41a1c","#e41a1c","#4daf4a","#e41a1c","#e41a1c","#377eb8","#4daf4a","#e41a1c","#e41a1c","#999999","#377eb8","#999999","#4daf4a","#377eb8","#999999","#e41a1c","#e41a1c","#4daf4a","#377eb8","#377eb8","#4daf4a","#4daf4a","#4daf4a","#4daf4a","#4daf4a","#e41a1c","#e41a1c","#4daf4a","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#999999","#377eb8","#377eb8","#e41a1c","#4daf4a","#377eb8","#4daf4a","#377eb8","#e41a1c","#e41a1c","#377eb8","#4daf4a","#4daf4a","#4daf4a","#377eb8","#377eb8","#4daf4a","#4daf4a","#4daf4a","#377eb8","#377eb8","#4daf4a","#4daf4a","#999999","#e41a1c","#e41a1c","#4daf4a","#377eb8","#377eb8","#999999","#377eb8","#4daf4a","#377eb8","#e41a1c","#4daf4a","#999999","#e41a1c","#e41a1 ...

# %%
hdbscan_ = hdbscan.HDBSCAN(min_samples=15)
# %memit hdbscan_.fit(X_aniso)
# %timeit hdbscan_.fit(X_aniso)
hdbscan_.fit(X_aniso)
y_pred = np.array(hdbscan_.labels_)
p3 = plot_cluster(X_aniso, y_pred, title="hdbscan")
show(p3)
# Out:
# peak memory: 187.76 MiB, increment: 0.00 MiB
# 100 loops, best of 3: 15.8 ms per loop
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a23b4236-53c2-4a79-bd32-957a2482085c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a23b4236-53c2-4a79-bd32-957a2482085c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a23b4236-53c2-4a79-bd32-957a2482085c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a23b4236-53c2-4a79-bd32-957a2482085c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"57ac5f41-bf11-4ab3-87c1-aa80a10d1d16":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"x":{"field":"x"},"y":{"field":"y"}},"id":"ec45f1f2-e208-4430-9501-2a92ab61e93f","type":"Circle"},{"attributes":{"below":[{"id":"3b3e9633-81a5-4f0b-b39c-789871fb773a","type":"LinearAxis"}],"left":[{"id":"ae24ae95-dfdc-4677-ab2a-14c391e1bf0b","type":"LinearAxis"}],"plot_height":450,"plot_width":500,"renderers":[{"id":"3b3e9633-81a5-4f0b-b39c-789871fb773a","type":"LinearAxis"},{"id":"c9943d76-1c2b-4713-af74-48a60bbefe67","type":"Grid"},{"id":"ae24ae95-dfdc-4677-ab2a-14c391e1bf0b","type":"LinearAxis"},{"id":"9757fef9-b9d8-4fce-9278-6f8332222a2a","type":"Grid"},{"id":"689615de-fb6f-4c88-afe3-5d2743d6f287","type":"BoxAnnotation"},{"id":"62455de5-8d56-468c-98b6-790fa2ee5efd","type":"GlyphRenderer"}],"title":{"id":"3589131f-c650-40ba-812e-b2a7857b65fc","type":"Title"},"tool_events":{"id":"7a286e16-78ec-41be-a14f-ced1fbaa0c60","type":"ToolEvents"},"toolbar":{"id":"3f65997f-a8e3-456c-a5bd-f3bc99d1cfc4","type":"Toolbar"},"x_range":{"id":"b26d7bce-962d-4d44-b9d1-c8dcd472f9b3","type":"DataRange1d"},"y_range":{"id":"587a330b-93d2-4f89-9376-6f64e09096fd","type":"DataRange1d"}},"id":"3af31a08-93c3-48fd-a865-2b5fd1969207","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"component 1","formatter":{"id":"b1b0e19f-a8ca-47e5-86f5-58f805ca3f7b","type":"BasicTickFormatter"},"plot":{"id":"3af31a08-93c3-48fd-a865-2b5fd1969207","subtype":"Figure","type":"Plot"},"ticker":{"id":"27d744ff-8650-4f25-bb9e-97fbe1a8636f","type":"BasicTicker"}},"id":"3b3e9633-81a5-4f0b-b39c-789871fb773a","type":"LinearAxis"},{"attributes":{},"id":"ade1cf52-0215-4f2a-ab20-344c337fb098","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","fill_color"],"data":{"fill_color":["#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#e41a1c","#e41a1c","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#e41a1c","#e41a1c","#e41a1c","#e41a1c","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#e41a1c","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#e41a1c","#377eb8","#e41a1c","#e41a1c","#e41a1c","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#e41a1c","#e41a1c","#e41a1c","#377eb8","#e41a1c","#377eb8","#377eb8","#e41a1c","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1c","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#e41a1c","#377eb8","#377eb8","#377eb8","#377eb8","#e41a1c","#377eb8","#e41a1 ...

# %% [markdown]
# ### Conclusion
# * performance-wise, scikit learn and pyclustering does a good job distinguishing close clusters, while hbscan have a hard time distinguishing clusters too close. Otherwise all three give similar results
# * Speed wise, for the same data, sklearn takes 8ms, hdbscan takes 17ms, while pyclustering takes 1.66 seconds
# * memory wise, all three methods takes a 187 MB peak memory, probably by precomputing a pair-wise distance matrix.
