# %%
from bert_embedding import BertEmbedding

# %%
sentences = ["hello molly", "hello molly"]

# %%
bert_embedding = BertEmbedding()

# %%
result = bert_embedding(sentences)

# %%
result[0][0]
# Out:
# ['hello', 'molly']

# %%
result[1][0]
# Out:
# ['hello', 'molly']

# %%
import numpy as np
import torch

# %%
torch.tensor(np.stack(result[0][1], axis=0)).shape
# Out:
# torch.Size([2, 768])

# %%
result[1][1][1]
# Out:
# array([ 2.20442623e-01, -6.07667714e-02, -6.50373474e-03, -5.02921343e-01,
#         3.01828206e-01, -2.50550769e-02,  6.85664594e-01,  3.09313595e-01,
#        -4.38076198e-01, -7.14264870e-01, -1.07476801e-01,  1.71676382e-01,
#         5.13163626e-01,  4.57360148e-02, -1.32080114e+00, -2.06060350e-01,
#        -3.43862250e-02,  4.62186545e-01,  1.89869910e-01,  2.05698572e-02,
#         7.42040634e-01,  1.01427197e-01,  7.88845569e-02, -6.56437755e-01,
#         1.37895554e-01,  2.37728819e-01, -1.24614395e-01,  3.24924558e-01,
#        -3.53629470e-01,  3.96609187e-01,  5.42140268e-02, -3.83754522e-01,
#         1.28363502e+00,  8.68557334e-01, -4.92789507e-01,  3.86184990e-01,
#         2.93559402e-01, -5.33018261e-02, -8.62947762e-01,  4.84161019e-01,
#         1.33525565e-01, -8.32062364e-01,  1.67745054e-01, -1.21239029e-01,
#        -2.53090203e-01,  6.50204122e-02, -1.37081251e-01, -5.37048221e-01,
# ...
