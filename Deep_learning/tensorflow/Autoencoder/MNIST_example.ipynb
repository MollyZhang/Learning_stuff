# %%
import numpy as np
import tensorflow.contrib.layers as lays
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from skimage import transform
from matplotlib import pyplot as plt
# Out:
# /home/molly/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def autoencoder(inputs):
    # encoder
    # 32 x 32 x 1   ->  16 x 16 x 32
    # 16 x 16 x 32  ->  8 x 8 x 16
    # 8 x 8 x 16    ->  2 x 2 x 8
    net = lays.conv2d(inputs, 32, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d(net, 16, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d(net, 8, [5, 5], stride=4, padding='SAME')
    # decoder
    # 2 x 2 x 8    ->  8 x 8 x 16
    # 8 x 8 x 16   ->  16 x 16 x 32
    # 16 x 16 x 32  ->  32 x 32 x 1
    net = lays.conv2d_transpose(net, 16, [5, 5], stride=4, padding='SAME')
    net = lays.conv2d_transpose(net, 32, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d_transpose(net, 1, [5, 5], stride=2, padding='SAME', activation_fn=tf.nn.tanh)
    return net


def resize_batch(imgs):
    # A function to resize a batch of MNIST images to (32, 32)
    # Args:
    #   imgs: a numpy array of size [batch_size, 28 X 28].
    # Returns:
    #   a numpy array of size [batch_size, 32, 32].
    imgs = imgs.reshape((-1, 28, 28, 1))
    resized_imgs = np.zeros((imgs.shape[0], 32, 32, 1))
    for i in range(imgs.shape[0]):
        resized_imgs[i, ..., 0] = transform.resize(imgs[i, ..., 0], (32, 32))
    return resized_imgs

# %%
ae_inputs = tf.placeholder(tf.float32, (None, 32, 32, 1))  # input to the network (MNIST images)
ae_outputs = autoencoder(ae_inputs)  # create the Autoencoder network
# calculate the loss and optimize the network
loss = tf.reduce_mean(tf.square(ae_outputs - ae_inputs))  # claculate the mean square error loss
train_op = tf.train.AdamOptimizer().minimize(loss)
# initialize the network
init = tf.global_variables_initializer()

batch_size = 500  # Number of samples in each batch
epoch_num = 5     # Number of epochs to train the network
lr = 0.001        # Learning rate

# read MNIST dataset
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# calculate the number of batches per epoch
batch_per_ep = mnist.train.num_examples // batch_size

with tf.Session() as sess:
    sess.run(init)
    for ep in range(epoch_num):  # epochs loop
        for batch_n in range(batch_per_ep):  # batches loop
            batch_img, batch_label = mnist.train.next_batch(batch_size)  # read a batch
            batch_img = batch_img.reshape((-1, 28, 28, 1)) # reshape each sample to an (28, 28) image
            batch_img = resize_batch(batch_img) # reshape the images to (32, 32)
            _, c = sess.run([train_op, loss], feed_dict={ae_inputs: batch_img})
            print('Epoch: {} - cost= {:.5f}'.format((ep + 1), c))

    # test the trained network
    batch_img, batch_label = mnist.test.next_batch(50)
    batch_img = resize_batch(batch_img)
    recon_img = sess.run([ae_outputs], feed_dict={ae_inputs: batch_img})[0]
    
    # test the trained network
    batch_img, batch_label = mnist.test.next_batch(50)
    batch_img = resize_batch(batch_img)
    recon_img = sess.run([ae_outputs], feed_dict={ae_inputs: batch_img})[0]

    # plot the reconstructed images and their ground truths (inputs)
    plt.figure(1)
    plt.title('Reconstructed Images')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(recon_img[i, ..., 0], cmap='gray')
    plt.figure(2)
    plt.title('Input Images')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(batch_img[i, ..., 0], cmap='gray')
    plt.show()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# /home/molly/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Epoch: 1 - cost= 0.10125
# Epoch: 1 - cost= 0.10130
# Epoch: 1 - cost= 0.09890
# Epoch: 1 - cost= 0.09662
# Epoch: 1 - cost= 0.09982
# Epoch: 1 - cost= 0.09409
# Epoch: 1 - cost= 0.09266
# Epoch: 1 - cost= 0.08808
# Epoch: 1 - cost= 0.08527
# Epoch: 1 - cost= 0.08270
# Epoch: 1 - cost= 0.07842
# Epoch: 1 - cost= 0.07441
# Epoch: 1 - cost= 0.07504
# Epoch: 1 - cost= 0.07637
# Epoch: 1 - cost= 0.07496
# Epoch: 1 - cost= 0.07245
# Epoch: 1 - cost= 0.06924
# Epoch: 1 - cost= 0.06866
# Epoch: 1 - cost= 0.06839
# Epoch: 1 - cost= 0.06839
# Epoch: 1 - cost= 0.06852
# Epoch: 1 - cost= 0.06724
# Epoch: 1 - cost= 0.06607
# Epoch: 1 - cost= 0.06411
# Epoch: 1 - cost= 0.06545
# Epoch: 1 - cost= 0.06216
# Epoch: 1 - cost= 0.06356
# Epoch: 1 - cost= 0.06132
# Epoch: 1 - cost= 0.06209
# Epoch: 1 - cost= 0.06155
# Epoch: 1 - cost= 0.06212
# Epoch: 1 - cost= 0.05912
# Epoch: 1 - cost= 0.05788
# Epoch: 1 - cost= 0.05747
# Epoch: 1 - cost= 0.05626
# Epoch: 1 - cost= 0.05545
# Epoch: 1 - cost= 0.05602
# Epoch: 1 - cost= 0.05711
# Epoch: 1 - cost= 0.05678
# Epoch: 1 - cost= 0.05624
# Epoch: 1 - cost= 0.05434
# Epoch: 1 - cost= 0.05411
# Epoch: 1 - cost= 0.05262
# Epoch: 1 - cost= 0.05313
# Epoch: 1 - cost= 0.05309
# Epoch: 1 - cost= 0.05285
# Epoch: 1 - cost= 0.05251
# Epoch: 1 - cost= 0.05198
# Epoch: 1 - cost= 0.05182
# Epoch: 1 - cost= 0.05193
# Epoch: 1 - cost= 0.05161
# Epoch: 1 - cost= 0.05151
# Epoch: 1 - cost= 0.04906
# Epoch: 1 - cost= 0.04931
# Epoch: 1 - cost= 0.04932
# Epoch: 1 - cost= 0.04952
# Epoch: 1 - cost= 0.04877
# Epoch: 1 - cost= 0.04810
# Epoch: 1 - cost= 0.04812
# Epoch: 1 - cost= 0.04778
# Epoch: 1 - cost= 0.04768
# Epoch: 1 - cost= 0.04641
# Epoch: 1 - cost= 0.04666
# Epoch: 1 - cost= 0.04540
# Epoch: 1 - cost= 0.04485
# Epoch: 1 - cost= 0.04394
# Epoch: 1 - cost= 0.04428
# Epoch: 1 - cost= 0.04305
# Epoch: 1 - cost= 0.04342
# Epoch: 1 - cost= 0.04304
# Epoch: 1 - cost= 0.04121
# Epoch: 1 - cost= 0.04098
# Epoch: 1 - cost= 0.04172
# Epoch: 1 - cost= 0.04024
# Epoch: 1 - cost= 0.03940
# Epoch: 1 - cost= 0.03952
# Epoch: 1 - cost= 0.03914
# Epoch: 1 - cost= 0.03952
# Epoch: 1 - cost= 0.03816
# Epoch: 1 - cost= 0.03734
# Epoch: 1 - cost= 0.03647
# Epoch: 1 - cost= 0.03681
# Epoch: 1 - cost= 0.03683
# Epoch: 1 - cost= 0.03546
# Epoch: 1 - cost= 0.03625
# Epoch: 1 - cost= 0.03475
# Epoch: 1 - cost= 0.03420
# Epoch: 1 - cost= 0.03276
# Epoch: 1 - cost= 0.03284
# Epoch: 1 - cost= 0.03365
# Epoch: 1 - cost= 0.03251
# Epoch: 1 - cost= 0.03263
# Epoch: 1 - cost= 0.03250
# Epoch: 1 - cost= 0.03131
# Epoch: 1 - cost= 0.03100
# Epoch: 1 - cost= 0.02971
# Epoch: 1 - cost= 0.03068
# Epoch: 1 - cost= 0.02946
# Epoch: 1 - cost= 0.02989
# Epoch: 1 - cost= 0.02923
# Epoch: 1 - cost= 0.02953
# Epoch: 1 - cost= 0.02851
# Epoch: 1 - cost= 0.02841
# Epoch: 1 - cost= 0.02827
# Epoch: 1 - cost= 0.02819
# Epoch: 1 - cost= 0.02726
# Epoch: 1 - cost= 0.02764
# Epoch: 1 - cost= 0.02690
# Epoch: 1 - cost= 0.02613
# Epoch: 1 - cost= 0.02667
# Epoch: 2 - cost= 0.02558
# Epoch: 2 - cost= 0.02593
# Epoch: 2 - cost= 0.02602
# Epoch: 2 - cost= 0.02560
# Epoch: 2 - cost= 0.02511
# Epoch: 2 - cost= 0.02460
# Epoch: 2 - cost= 0.02494
# Epoch: 2 - cost= 0.02480
# Epoch: 2 - cost= 0.02372
# Epoch: 2 - cost= 0.02424
# Epoch: 2 - cost= 0.02444
# Epoch: 2 - cost= 0.02366
# Epoch: 2 - cost= 0.02387
# Epoch: 2 - cost= 0.02403
# Epoch: 2 - cost= 0.02276
# Epoch: 2 - cost= 0.02285
# Epoch: 2 - cost= 0.02301
# Epoch: 2 - cost= 0.02180
# Epoch: 2 - cost= 0.02260
# Epoch: 2 - cost= 0.02214
# Epoch: 2 - cost= 0.02250
# Epoch: 2 - cost= 0.02178
# Epoch: 2 - cost= 0.02131
# Epoch: 2 - cost= 0.02122
# Epoch: 2 - cost= 0.02092
# Epoch: 2 - cost= 0.02102
# Epoch: 2 - cost= 0.02115
# Epoch: 2 - cost= 0.02156
# Epoch: 2 - cost= 0.02099
# Epoch: 2 - cost= 0.02079
# Epoch: 2 - cost= 0.02091
# Epoch: 2 - cost= 0.02106
# Epoch: 2 - cost= 0.02029
# Epoch: 2 - cost= 0.02024
# Epoch: 2 - cost= 0.01983
# Epoch: 2 - cost= 0.01968
# Epoch: 2 - cost= 0.01968
# Epoch: 2 - cost= 0.02016
# Epoch: 2 - cost= 0.02008
# Epoch: 2 - cost= 0.01951
# Epoch: 2 - cost= 0.01988
# Epoch: 2 - cost= 0.01941
# Epoch: 2 - cost= 0.01909
# Epoch: 2 - cost= 0.01888
# Epoch: 2 - cost= 0.01865
# Epoch: 2 - cost= 0.01922
# Epoch: 2 - cost= 0.01871
# Epoch: 2 - cost= 0.01924
# Epoch: 2 - cost= 0.01862
# Epoch: 2 - cost= 0.01851
# Epoch: 2 - cost= 0.01844
# Epoch: 2 - cost= 0.01856
# Epoch: 2 - cost= 0.01825
# Epoch: 2 - cost= 0.01848
# Epoch: 2 - cost= 0.01769
# Epoch: 2 - cost= 0.01789
# Epoch: 2 - cost= 0.01808
# Epoch: 2 - cost= 0.01826
# Epoch: 2 - cost= 0.01796
# Epoch: 2 - cost= 0.01779
# Epoch: 2 - cost= 0.01746
# Epoch: 2 - cost= 0.01788
# Epoch: 2 - cost= 0.01721
# Epoch: 2 - cost= 0.01787
# Epoch: 2 - cost= 0.01689
# Epoch: 2 - cost= 0.01758
# Epoch: 2 - cost= 0.01698
# Epoch: 2 - cost= 0.01730
# Epoch: 2 - cost= 0.01658
# Epoch: 2 - cost= 0.01667
# Epoch: 2 - cost= 0.01720
# Epoch: 2 - cost= 0.01643
# Epoch: 2 - cost= 0.01628
# Epoch: 2 - cost= 0.01614
# Epoch: 2 - cost= 0.01644
# Epoch: 2 - cost= 0.01702
# Epoch: 2 - cost= 0.01631
# Epoch: 2 - cost= 0.01688
# Epoch: 2 - cost= 0.01610
# Epoch: 2 - cost= 0.01590
# Epoch: 2 - cost= 0.01574
# Epoch: 2 - cost= 0.01573
# Epoch: 2 - cost= 0.01626
# Epoch: 2 - cost= 0.01583
# Epoch: 2 - cost= 0.01583
# Epoch: 2 - cost= 0.01534
# Epoch: 2 - cost= 0.01577
# Epoch: 2 - cost= 0.01599
# Epoch: 2 - cost= 0.01536
# Epoch: 2 - cost= 0.01529
# Epoch: 2 - cost= 0.01590
# Epoch: 2 - cost= 0.01541
# Epoch: 2 - cost= 0.01564
# Epoch: 2 - cost= 0.01567
# Epoch: 2 - cost= 0.01469
# Epoch: 2 - cost= 0.01538
# Epoch: 2 - cost= 0.01494
# Epoch: 2 - cost= 0.01488
# Epoch: 2 - cost= 0.01510
# Epoch: 2 - cost= 0.01467
# Epoch: 2 - cost= 0.01485
# Epoch: 2 - cost= 0.01451
# Epoch: 2 - cost= 0.01482
# Epoch: 2 - cost= 0.01458
# Epoch: 2 - cost= 0.01499
# Epoch: 2 - cost= 0.01491
# Epoch: 2 - cost= 0.01428
# Epoch: 2 - cost= 0.01477
# Epoch: 2 - cost= 0.01439
# Epoch: 2 - cost= 0.01426
# Epoch: 3 - cost= 0.01437
# Epoch: 3 - cost= 0.01454
# Epoch: 3 - cost= 0.01400
# Epoch: 3 - cost= 0.01355
# Epoch: 3 - cost= 0.01440
# Epoch: 3 - cost= 0.01373
# Epoch: 3 - cost= 0.01411
# Epoch: 3 - cost= 0.01449
# Epoch: 3 - cost= 0.01438
# Epoch: 3 - cost= 0.01414
# Epoch: 3 - cost= 0.01336
# Epoch: 5 - cost= 0.00880
# Epoch: 5 - cost= 0.00869
# Epoch: 5 - cost= 0.00865
# Epoch: 5 - cost= 0.00886
# Epoch: 5 - cost= 0.00923
# Epoch: 5 - cost= 0.00888
# Epoch: 5 - cost= 0.00876
# Epoch: 5 - cost= 0.00864
# Epoch: 5 - cost= 0.00907
# Epoch: 5 - cost= 0.00887
# Epoch: 5 - cost= 0.00853
# Epoch: 5 - cost= 0.00897
# Epoch: 5 - cost= 0.00846
# Epoch: 5 - cost= 0.00895
# Epoch: 5 - cost= 0.00893
# Epoch: 5 - cost= 0.00814
# Epoch: 5 - cost= 0.00857
# Epoch: 5 - cost= 0.00863
# Epoch: 5 - cost= 0.00884
# Epoch: 5 - cost= 0.00834
# Epoch: 5 - cost= 0.00835
# Epoch: 5 - cost= 0.00870
# Epoch: 5 - cost= 0.00886
# Epoch: 5 - cost= 0.00845
# Epoch: 5 - cost= 0.00879
# Epoch: 5 - cost= 0.00866
# Epoch: 5 - cost= 0.00887
# Epoch: 5 - cost= 0.00853
# Epoch: 5 - cost= 0.00874
# Epoch: 5 - cost= 0.00860
# Epoch: 5 - cost= 0.00876
# Epoch: 5 - cost= 0.00844
# Epoch: 5 - cost= 0.00870
# Epoch: 5 - cost= 0.00855
# Epoch: 5 - cost= 0.00848
# Epoch: 5 - cost= 0.00824
# Epoch: 5 - cost= 0.00859
# Epoch: 5 - cost= 0.00857
# Epoch: 5 - cost= 0.00876
# Epoch: 5 - cost= 0.00833
# Epoch: 5 - cost= 0.00886
# Epoch: 5 - cost= 0.00851
# Epoch: 5 - cost= 0.00847
# Epoch: 5 - cost= 0.00830
# Epoch: 5 - cost= 0.00815
# Epoch: 5 - cost= 0.00871
# Epoch: 5 - cost= 0.00840
# Epoch: 5 - cost= 0.00871
# Epoch: 5 - cost= 0.00836
# Epoch: 5 - cost= 0.00859
# Epoch: 5 - cost= 0.00822
# Epoch: 5 - cost= 0.00867
# Epoch: 5 - cost= 0.00836
# Epoch: 5 - cost= 0.00837
# Epoch: 5 - cost= 0.00832
# Epoch: 5 - cost= 0.00822
# Epoch: 5 - cost= 0.00842
# Epoch: 5 - cost= 0.00816
# Epoch: 5 - cost= 0.00846
# Epoch: 5 - cost= 0.00890
# Epoch: 5 - cost= 0.00817
# Epoch: 5 - cost= 0.00850
# Epoch: 5 - cost= 0.00850
# Epoch: 5 - cost= 0.00839
# Epoch: 5 - cost= 0.00818
# Epoch: 5 - cost= 0.00853
# Epoch: 5 - cost= 0.00869
# Epoch: 5 - cost= 0.00827
# Epoch: 5 - cost= 0.00803
# Epoch: 5 - cost= 0.00842
# Epoch: 5 - cost= 0.00816
# Epoch: 5 - cost= 0.00832
# Epoch: 5 - cost= 0.00805
# Epoch: 5 - cost= 0.00803
# Epoch: 5 - cost= 0.00844
# Epoch: 5 - cost= 0.00833
# Epoch: 5 - cost= 0.00880
# Epoch: 5 - cost= 0.00824
# Epoch: 5 - cost= 0.00836
# Epoch: 5 - cost= 0.00836
